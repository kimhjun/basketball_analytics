# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/malik.csv')

# %%
df = df.set_index('Date')

# %%
df = df[df['GS'] != 'Did Not Play']

# %%
df.iloc[63]
# Out:
# Rk                     1
# G                      1
# Age               20-255
# Tm                   CHO
# Unnamed: 5           NaN
# Opp                  MIL
# Unnamed: 7        L (-1)
# GS                     0
# MP                 33:35
# FG                     7
# FGA                   16
# FG%                 .438
# 3P                     4
# 3PA                    8
# 3P%                 .500
# FT                     0
# FTA                    0
# FT%                  NaN
# ORB                    0
# DRB                    4
# TRB                    4
# AST                    2
# STL                    1
# BLK                    2
# TOV                    0
# PF                     1
# PTS                   18
# GmSc                14.2
# +/-                   +5
# rolling_3              0
# rolling_avg_3    13.2667
# rolling_avg_5      15.32
# Name: 2018-10-17, dtype: object

# %%
df['rolling_avg_3'] = df['GmSc'].rolling(window=3).mean()
df['rolling_avg_5'] = df['GmSc'].rolling(window=5).mean()

# %%
fig, ax = plt.subplots()
plt.title('3 games moving average of the Game Score of Malik Monk\n(The red line indicates the start of 2018/19 season)')
ax.axvline(63, linewidth=2, color='r')
df['rolling_avg_3'].plot()

# %%
df.index
# Out:
# Index(['2017-10-18', '2017-10-20', '2017-10-23', '2017-10-25', '2017-10-27',
#        '2017-10-29', '2017-10-30', '2017-11-01', '2017-11-03', '2017-11-05',
#        ...
#        '2019-01-14', '2019-01-17', '2019-01-19', '2019-01-20', '2019-01-23',
#        '2019-01-25', '2019-01-28', '2019-01-30', '2019-02-01', '2019-02-02'],
#       dtype='object', name='Date', length=112)

# %%
df['rolling_3'] = sum(df.iloc[i-3:i]['GmSc']) / 3

# %%
df.iloc[3:5]['GmSc'].map(lambda x : float(x))
# Out:
# Date
# 2017-10-25    12.2
# 2017-10-27     8.2
# Name: GmSc, dtype: float64

# %%
df
# Out:
#             Rk     G     Age   Tm Unnamed: 5  Opp Unnamed: 7 GS     MP  FG  \
# Date
# 2017-10-18   1   1.0  19-256  CHO          @  DET    L (-12)  0  21:28   1
# 2017-10-20   2   2.0  19-258  CHO        NaN  ATL    W (+18)  0  18:36   2
# 2017-10-23   3   3.0  19-261  CHO          @  MIL     L (-9)  0  18:02   1
# 2017-10-25   4   4.0  19-263  CHO        NaN  DEN    W (+17)  0  25:02   7
# 2017-10-27   5   5.0  19-265  CHO        NaN  HOU    L (-16)  0  27:43   3
# 2017-10-29   6   6.0  19-267  CHO        NaN  ORL     W (+7)  0  17:57   1
# 2017-10-30   7   7.0  19-268  CHO          @  MEM     W (+5)  0  23:39   5
# 2017-11-01   8   8.0  19-270  CHO        NaN  MIL     W (+5)  0  22:39  10
# 2017-11-03   9   9.0  19-272  CHO          @  SAS     L (-7)  0  17:53   1
# 2017-11-05  10  10.0  19-274  CHO          @  MIN    L (-18)  0  20:24   2
# 2017-11-07  11  11.0  19-276  CHO          @  NYK     L (-5)  0  26:42   8
# ...
