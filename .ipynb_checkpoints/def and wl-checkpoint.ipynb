# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
d_set = pd.read_csv('data/20190131_defence_team.csv')
d_set = d_set.set_index('Team')

# %%
d_set
# Out:
#                         Rk Conf Div   W   L   W/L%    MOV    ORtg    DRtg  \
# Team
# Milwaukee Bucks          1    E   C  36  13  0.735   9.65  113.97  104.81
# Oklahoma City Thunder    3    W  NW  32  18  0.640   5.02  110.74  105.84
# Indiana Pacers           4    E   C  32  18  0.640   4.40  110.52  106.05
# Boston Celtics           5    E   A  32  19  0.627   6.80  112.95  106.11
# Utah Jazz                2    W  NW  29  23  0.558   2.98  109.06  106.17
# Miami Heat               9    E  SE  24  25  0.490  -0.16  107.93  108.06
# Memphis Grizzlies        6    W  SW  20  32  0.385  -3.23  104.87  108.29
# Los Angeles Lakers       7    W   P  26  25  0.510   0.22  108.62  108.34
# Toronto Raptors          8    E   A  37  15  0.712   5.40  113.86  108.46
# Denver Nuggets          11    W  NW  35  15  0.700   5.68  114.99  109.13
# Philadelphia 76ers      14    E   A  33  18  0.647   3.61  113.08  109.55
# Detroit Pistons         12    E   C  21  28  0.429  -2.78  106.82  109.60
# ...

# %%
plt.scatter(d_set['DRtg'], d_set['DFG%'])

# %%
plt.scatter(d_set['DRtg/A'], d_set['DFG%'])

# %%
plt.scatter(d_set['DRtg/A'], d_set['DFGA'])

# %%
plt.scatter(d_set['DRtg'], d_set['DFGA'])

# %%
plt.scatter(d_set['NRtg'], d_set['W/L%'])

# %%
plt.scatter(d_set['DRtg'], d_set['W/L%'])

# %%
plt.scatter(d_set['ORtg'], d_set['W/L%'])

# %%
plt.scatter(d_set['DRtg/A'], d_set['W/L%'])
