# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
plt.style.use('seaborn')
# %matplotlib inline

# %%
d_set = pd.read_csv('data/190520_combine.csv', encoding='utf-8')
d_set = d_set.set_index('PLAYER')

# %%
d_set_2 = pd.read_csv('data/190519_combine.csv', encoding='utf-8')
d_set_2 = d_set_2.set_index('PLAYER')

# %%
pos_map = {
    "SG":"Guard",
    "PG": "Guard",
    "SF": "Forward",
    "PF": "Forward",
    "SF-PF": "Forward",
    "SG-SF": "G/F",
    "PG-SG": "Guard",
    "C": "Center"    
}

d_set['POS_abb'] = d_set.POS.apply(lambda x : pos_map[x])

d_set["height_w/o_shoes(cm)"] = d_set["height_w/o_shoes"].map(lambda x: round((float(x.split("'")[1]) / 12) +  float(x.split("'")[0])) * 30.25, 2)
d_set["wingspan(cm)"] = d_set["wingspan"].map(lambda x: round((float(x.split("'")[1]) / 12) +  float(x.split("'")[0])) * 30.25, 2)

d_set["height_w/o_shoes_f"] = d_set["height_w/o_shoes"].map(lambda x: float(x.split("'")[0]))
d_set["height_w/o_shoes_in"] = d_set["height_w/o_shoes"].map(lambda x: float(x.split("'")[1]) / 12)
d_set["height_w/o_shoes(cm)"] = round((d_set["height_w/o_shoes_f"] + d_set["height_w/o_shoes_in"]) * 30.25, 2)
d_set["wingspan(cm)"] = d_set["wingspan"].map(lambda x: round((float(x.split("'")[0]) + float(x.split("'")[1]) / 12)*30.25, 2))
merged_set = pd.merge(d_set, d_set_2, left_index=True, right_index=True)
merged_set = merged_set.rename(columns={'POS_x':'POS'}).drop(['POS_y'], axis=1)

# %%
merged_set = merged_set[['POS_abb', 'height_w/o_shoes(cm)', 'wingspan(cm)', 'Lane Agility Time', 'Standing Vertical Leap', 'Standing Reach']]
merged_set['SVL(cm)'] = merged_set['Standing Vertical Leap'] * 30.25 / 12
# Out:
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
merged_set
# Out:
#                         POS_abb  height_w/o_shoes(cm)  wingspan(cm)  \
# PLAYER
# Naz Reid                Forward                203.56        219.94
# Shamorie Ponds            Guard                180.24        190.32
# Dedric Lawson           Forward                199.15        217.42
# Charles Bassey           Center                203.56        220.57
# Quentin Grimes            Guard                191.58        201.04
# Talen Horton-Tucker       Guard                187.80        214.90
# Moses Brown              Center                214.90        223.72
# Zach Norvell Jr.          Guard                192.84        196.62
# Jordan Poole              Guard                190.32        198.52
# Tacko Fall               Center                224.98        247.67
# Admiral Schofield       Forward                191.58        206.08
# Jalen Hoard             Forward                199.78        213.64
# Reggie Perry            Forward                201.67        213.01
# Tremont Waters            Guard                175.20        187.17
# Brian Bowen II          Forward                197.26        206.71
# Ty Jerome                 Guard                192.21        191.58
# Eric Paschall           Forward                196.62        211.12
# Neemias Queta            Center                208.60        222.46
# Simisola Shittu         Forward                202.93        214.90
# Tyler Cook              Forward                199.78        213.01
# Dewan Hernandez          Center                204.19        216.16
# Jaylen Nowell             Guard                189.69        199.78
# Quinndary Weatherspoon    Guard                189.06        204.19
# Ignas Brazdeikis        Forward                195.99        204.82
# Devon Dotson              Guard                181.50        189.69
# Daniel Gafford          Forward                204.82        217.42
# Nassir Little           Forward                192.84        214.90
# Cameron Johnson           Guard                199.15        206.71
# Kyle Guy                  Guard                183.39        192.84
# Jalen McDaniels         Forward                202.30        212.38
# Luka Samanic            Forward                205.45        207.97
# Carsen Edwards            Guard                178.35        196.62
# Bruno Fernando           Center                203.56        219.94
# Grant Williams          Forward                195.99        206.08
# Jaylen Hands              Guard                185.28        195.36
# Mfiondu Kabengele       Forward                203.56        219.31
# Kevin Porter Jr.          Guard                191.58        204.19
# Jordan Bone               Guard                185.28        189.69
# Luguentz Dort             Guard                188.43        202.93
# Jaxson Hayes            Forward                207.34        220.57
# Cody Martin               Guard                193.47        207.34
# Ky Bowman                 Guard                184.02        199.15
# Brandon Clarke          Forward                199.78        202.30
# Miye Oni                  Guard                192.21        208.60
# Kris Wilkes             Forward                197.26        208.60
# Louis King              Forward                198.52        212.38
# Marial Shayok           Forward                192.84        212.38
# KZ Okpala               Forward                199.78        216.16
# Dylan Windler           Forward                197.26        206.71
# Nicolas Claxton          Center                206.71        218.05
# Terence Davis             Guard                189.06        203.56
# Jalen Lecque              Guard                187.80        202.93
# Terance Mann                G/F                193.47        201.04
# Jared Harper              Guard                175.83        195.36
# Isaiah Roby             Forward                199.78        214.27
# Charles Matthews          Guard                194.10        205.45
# Darius Bazley           Forward                201.04        211.75
# Oshea Brissett          Forward                199.15        211.75
#
#                         Lane Agility Time  Standing Vertical Leap  \
# PLAYER
# Naz Reid                            12.03                    26.0
# Shamorie Ponds                      11.01                    29.0
# Dedric Lawson                       11.80                    23.5
# Charles Bassey                      12.65                    29.0
# Quentin Grimes                      10.83                    27.5
# Talen Horton-Tucker                 11.34                    26.0
# Moses Brown                         11.95                    27.0
# Zach Norvell Jr.                    11.60                    24.0
# Jordan Poole                        10.59                    27.5
# Tacko Fall                          13.01                    22.0
# Admiral Schofield                   10.77                    30.0
# Jalen Hoard                         11.44                    27.5
# Reggie Perry                        12.46                    28.5
# Tremont Waters                      10.76                    30.5
# Brian Bowen II                      10.98                    32.0
# Ty Jerome                           11.21                    26.0
# Eric Paschall                       11.63                    33.0
# Neemias Queta                       12.04                    24.0
# Simisola Shittu                     11.85                    27.0
# Tyler Cook                          11.32                    27.5
# Dewan Hernandez                     11.46                    30.5
# Jaylen Nowell                       10.76                    32.0
# Quinndary Weatherspoon              11.57                    31.0
# Ignas Brazdeikis                    11.06                    31.0
# Devon Dotson                        10.63                    30.0
# Daniel Gafford                      11.61                    32.5
# Nassir Little                       12.15                    31.0
# Cameron Johnson                     10.52                    30.5
# Kyle Guy                            10.48                    30.5
# Jalen McDaniels                     11.54                    29.5
# Luka Samanic                        11.01                    27.0
# Carsen Edwards                      10.53                    28.5
# Bruno Fernando                      11.29                    29.5
# Grant Williams                      10.83                    26.0
# Jaylen Hands                        10.73                    33.0
# Mfiondu Kabengele                   11.21                    28.0
# Kevin Porter Jr.                    10.82                    27.0
# Jordan Bone                          9.97                    36.0
# Luguentz Dort                       10.79                    32.5
# Jaxson Hayes                        11.74                    27.0
# Cody Martin                         10.44                    28.0
# Ky Bowman                           11.11                    27.5
# Brandon Clarke                      10.61                    34.0
# Miye Oni                            11.71                    30.5
# Kris Wilkes                         10.39                    29.5
# Louis King                          10.99                    29.0
# Marial Shayok                       11.16                    29.5
# KZ Okpala                           10.88                    30.5
# Dylan Windler                       10.70                    29.0
# Nicolas Claxton                     11.26                    31.5
# Terence Davis                       10.69                    29.5
# Jalen Lecque                        11.09                    35.0
# Terance Mann                        11.51                    32.5
# Jared Harper                        10.77                    33.5
# Isaiah Roby                         10.63                    32.5
# Charles Matthews                    11.26                    29.5
# Darius Bazley                       11.09                    30.5
# Oshea Brissett                      11.30                    34.0
#
#                        Standing Reach    SVL(cm)
# PLAYER
# Naz Reid                       9' 1''  65.541667
# Shamorie Ponds               8' 0.5''  73.104167
# Dedric Lawson               8' 11.5''  59.239583
# Charles Bassey               9' 1.5''  73.104167
# Quentin Grimes               8' 4.5''  69.322917
# Talen Horton-Tucker            8' 7''  65.541667
# Moses Brown                    9' 5''  68.062500
# Zach Norvell Jr.               8' 5''  60.500000
# Jordan Poole                 8' 3.5''  69.322917
# Tacko Fall                  10' 2.5''  55.458333
# Admiral Schofield            8' 6.5''  75.625000
# Jalen Hoard                  8' 9.5''  69.322917
# Reggie Perry                  8' 10''  71.843750
# Tremont Waters               7' 9.5''  76.885417
# Brian Bowen II                 8' 7''  80.666667
# Ty Jerome                      8' 2''  65.541667
# Eric Paschall                8' 7.5''  83.187500
# Neemias Queta                9' 3.5''  60.500000
# Simisola Shittu               8' 10''  68.062500
# Tyler Cook                  8' 10.5''  69.322917
# Dewan Hernandez               8' 11''  76.885417
# Jaylen Nowell                  8' 2''  80.666667
# Quinndary Weatherspoon         8' 4''  78.145833
# Ignas Brazdeikis               8' 6''  78.145833
# Devon Dotson                7' 11.5''  75.625000
# Daniel Gafford                 9' 2''  81.927083
# Nassir Little                8' 8.5''  78.145833
# Cameron Johnson                8' 7''  76.885417
# Kyle Guy                    7' 11.5''  76.885417
# Jalen McDaniels              8' 9.5''  74.364583
# Luka Samanic                  8' 11''  68.062500
# Carsen Edwards              7' 10.5''  71.843750
# Bruno Fernando                 9' 2''  74.364583
# Grant Williams               8' 8.5''  65.541667
# Jaylen Hands                   8' 1''  83.187500
# Mfiondu Kabengele            9' 1.5''  70.583333
# Kevin Porter Jr.               8' 7''  68.062500
# Jordan Bone                   7' 11''  90.750000
# Luguentz Dort                8' 3.5''  81.927083
# Jaxson Hayes                 9' 2.5''  68.062500
# Cody Martin                  8' 6.5''  70.583333
# Ky Bowman                      8' 2''  69.322917
# Brandon Clarke                 8' 6''  85.708333
# Miye Oni                     8' 4.5''  76.885417
# Kris Wilkes                    8' 7''  74.364583
# Louis King                   8' 8.5''  73.104167
# Marial Shayok                8' 7.5''  74.364583
# KZ Okpala                   8' 10.5''  76.885417
# Dylan Windler                8' 8.5''  73.104167
# Nicolas Claxton                9' 2''  79.406250
# Terence Davis                  8' 5''  74.364583
# Jalen Lecque                 8' 2.5''  88.229167
# Terance Mann                   8' 5''  81.927083
# Jared Harper                  7' 10''  84.447917
# Isaiah Roby                   8' 10''  81.927083
# Charles Matthews               8' 7''  74.364583
# Darius Bazley                 8' 11''  76.885417
# Oshea Brissett                 8' 8''  85.708333

# %%
#merged_set.plot.scatter(x='Lane Agility Time', y = 'height_w/o_shoes(cm)')

fig, ax = plt.subplots()
merged_set.plot.scatter('height_w/o_shoes(cm)', 'Lane Agility Time', figsize=(20, 10), fontsize=15, ax=ax)
for k, point in merged_set.iterrows():
    #if k in ["Rudy Gobert", "Joel Embiid", "Clint Capela"]:
    #    ax.annotate(str(k), (point['DFGA'], point['DFG%']), color='red', fontsize=15, fontweight='bold')
        
    if point['POS_abb'] == 'Guard':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['Lane Agility Time']), color='darkturquoise', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'G/F':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['Lane Agility Time']), color='darkcyan', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'Forward':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['Lane Agility Time']), color='darksalmon', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'C/F':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['Lane Agility Time']), color='indianred', fontsize=15, fontweight='bold')
    else:
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['Lane Agility Time']), color='orangered', fontsize=15, fontweight='bold')
plt.title('Combine result: height_w/o_shoes(cm) - Lane Agility Time', fontsize=20, fontweight="bold")
plt.xlabel('height_w/o_shoes(cm)', fontsize=15)
plt.ylabel('Lane Agility Time', fontsize=15)

g1_patch = mpatches.Patch(color='darkturquoise', label='Guard')
g2_patch = mpatches.Patch(color='darkcyan', label='G/F')
g3_patch = mpatches.Patch(color='darksalmon', label='Forward')
g4_patch = mpatches.Patch(color='indianred', label='C/F')
g5_patch = mpatches.Patch(color='orangered', label='Center')
plt.legend(handles=[g1_patch, g2_patch, g3_patch, g4_patch, g5_patch], fontsize=17)
ax.grid(False)

# %%
merged_set['Lane Agility Time'].div(merged_set['height_w/o_shoes(cm)']).sort_values()
# Out:
# PLAYER
# Kris Wilkes               0.052672
# Cameron Johnson           0.052825
# Brandon Clarke            0.053108
# Isaiah Roby               0.053209
# Luka Samanic              0.053590
# Jordan Bone               0.053810
# Cody Martin               0.053962
# Dylan Windler             0.054243
# KZ Okpala                 0.054460
# Nicolas Claxton           0.054472
# Mfiondu Kabengele         0.055070
# Darius Bazley             0.055163
# Grant Williams            0.055258
# Louis King                0.055360
# Bruno Fernando            0.055463
# Moses Brown               0.055607
# Jordan Poole              0.055643
# Brian Bowen II            0.055663
# Dewan Hernandez           0.056124
# Admiral Schofield         0.056217
# Ignas Brazdeikis          0.056431
# Kevin Porter Jr.          0.056478
# Quentin Grimes            0.056530
# Terence Davis             0.056543
# Jaxson Hayes              0.056622
# Tyler Cook                0.056662
# Daniel Gafford            0.056684
# Jaylen Nowell             0.056724
# Oshea Brissett            0.056741
# Jalen McDaniels           0.057044
# Kyle Guy                  0.057146
# Luguentz Dort             0.057263
# Jalen Hoard               0.057263
# Neemias Queta             0.057718
# Tacko Fall                0.057827
# Marial Shayok             0.057872
# Jaylen Hands              0.057912
# Charles Matthews          0.058011
# Ty Jerome                 0.058322
# Simisola Shittu           0.058395
# Devon Dotson              0.058567
# Carsen Edwards            0.059041
# Jalen Lecque              0.059052
# Naz Reid                  0.059098
# Eric Paschall             0.059150
# Dedric Lawson             0.059252
# Terance Mann              0.059492
# Zach Norvell Jr.          0.060153
# Ky Bowman                 0.060374
# Talen Horton-Tucker       0.060383
# Miye Oni                  0.060923
# Shamorie Ponds            0.061085
# Quinndary Weatherspoon    0.061198
# Jared Harper              0.061252
# Tremont Waters            0.061416
# Reggie Perry              0.061784
# Charles Bassey            0.062144
# Nassir Little             0.063006
# dtype: float64

# %%
d_set = pd.read_csv('data/190514_drive.csv')
d_set = d_set.set_index('Player')

# %%
d_set = pd.read_csv('data/190114_cs.csv')
d_set = d_set.set_index('Player')

# %%
d_set = pd.read_csv('data/190125_def.csv')
d_set = d_set.set_index('Player')
d_set = d_set.query('POS == "C/F" or POS == "Center"').copy()

# %%
d_set = pd.read_csv('data/190514_pullup.csv')
d_set = d_set.set_index('Player')

# %%
font = {'family' : 'consolas',
        'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %%
d_set['PTAS%'] = d_set['PTS%'] + d_set['AST%']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PTS%'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-24948907ed93> in <module>()
# ----> 1 d_set['PTAS%'] = d_set['PTS%'] + d_set['AST%']
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PTS%'

# %%
pos_map = {
    "SG":"Guard",
    "PG": "Guard",
    "SF": "Forward",
    "PF": "Forward",
    "SF-PF": "Forward",
    "SG-SF": "G/F",
    "PG-SG": "Guard",
    "C": "Center"    
}

# %%
d_set['POS_abb'] = d_set.POS.apply(lambda x : pos_map[x])

# %%
d_set.columns
# Out:
# Index(['POS', 'BODY FAT %', 'HAND LENGTH (inches)', 'HAND WIDTH (inches)',
#        'HEIGHT W/O SHOES', 'HEIGHT W/ SHOES', 'STANDING REACH', 'WEIGHT (LBS)',
#        'WINGSPAN', 'POS_abb'],
#       dtype='object')

# %%
fig, ax = plt.subplots(2, sharex=True)
ax[0].set_title('PTS% and AST% of players who attempt more than 10 drives per game (Conf. Semi-Finals)', fontsize=20, fontweight="bold")
d_set.plot.scatter('DRIVES', 'PTS%', figsize=(20, 10), fontsize=15, ax=ax[0])
for k, point in d_set.iterrows():
    if k in ["Giannis Antetokounmpo", "James Harden", "CJ McCollum", "Kawhi Leonard"]:
        ax[0].annotate(str(k), (point['DRIVES'], point['PTS%']), color='blue', fontsize=15, fontweight='bold')
    else:
        ax[0].annotate(str(k), (point['DRIVES'], point['PTS%']), color='darkcyan', fontsize=15, fontweight='bold')

plt.xlabel('DRIVES PER GAME', fontsize=15)
plt.ylabel('PTS%', fontsize=15)
ax[0].grid(False)

#fig2, ax2 = plt.subplots(1, 2, 2, sharex=ax1)
d_set.plot.scatter('DRIVES', 'AST%', figsize=(20, 10), fontsize=15, ax=ax[1])
for k, point in d_set.iterrows():
    if k in ["James Harden", "Giannis Antetokounmpo", "Kawhi Leonard"]:
        ax[1].annotate(str(k), (point['DRIVES'], point['AST%']), color='orangered', fontsize=15, fontweight='bold')
    else:
        ax[1].annotate(str(k), (point['DRIVES'], point['AST%']), color='darksalmon', fontsize=15, fontweight='bold')
#plt.title('PTS% of players who attempt more than 3 drives per game', fontsize=20, fontweight="bold")
#plt.xlabel('DRIVES PER GAME', fontsize=15)
#plt.ylabel('PTS%', fontsize=15)

ax[1].grid(False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DRIVES'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-b2cbda73778d> in <module>()
#       1 fig, ax = plt.subplots(2, sharex=True)
#       2 ax[0].set_title('PTS% and AST% of players who attempt more than 10 drives per game (Conf. Semi-Finals)', fontsize=20, fontweight="bold")
# ----> 3 d_set.plot.scatter('DRIVES', 'PTS%', figsize=(20, 10), fontsize=15, ax=ax[0])
#       4 for k, point in d_set.iterrows():
#       5     if k in ["Giannis Antetokounmpo", "James Harden", "CJ McCollum", "Kawhi Leonard"]:
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\hjunk\anaconda3\envs\henv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DRIVES'

# %%
fig, ax = plt.subplots()
d_set.plot.scatter('DRIVES', 'PTAS%', figsize=(20, 10), fontsize=15, ax=ax)
for k, point in d_set.iterrows():
    #if k in ["Rudy Gobert", "Joel Embiid", "Clint Capela"]:
    #    ax.annotate(str(k), (point['DFGA'], point['DFG%']), color='red', fontsize=15, fontweight='bold')
    ax.annotate(str(k), (point['DRIVES'], point['AST%']), color='darkcyan', fontsize=15, fontweight='bold')
plt.title('PTS% of players who attempt more than 3 drives per game', fontsize=20, fontweight="bold")
plt.xlabel('DRIVES PER GAME', fontsize=15)
plt.ylabel('PTS%', fontsize=15)

ax.grid(False)

# %%
plt.figure(figsize=(20, 10), dpi=80)
plt.scatter(x=d_set['PTS%'], y=d_set['AST%'], s=d_set['DRIVES'].values ** 4 /100, alpha=0.3)
#d_set.plot.scatter(x='PTS%', y='AST%', s='DRIVES'.values, figsize=(20, 10), fontsize=15, ax=ax)
for k, point in d_set.iterrows():
    if k in ["James Harden", "Chris Paul", "Jimmy Butler", "Kyrie Irving", "Jamal Murray", "Kevin Durant", "Giannis Antetokounmpo", "CJ McCollum", "Kawhi Leonard", "Damian Lillard"]:
        plt.annotate(str(k), (point['PTS%'], point['AST%']), color='orangered', fontsize=15, fontweight='bold')
    else:
        plt.annotate(str(k), (point['PTS%'], point['AST%']), color='darksalmon', fontsize=15, fontweight='bold')
plt.title('AST% / PTS% of players who drive over 8 times per game\n (Bold letters are top 10 guys on # of attempts)', fontsize=20, fontweight="bold")
plt.xlabel('PTS%', fontsize=15)
plt.ylabel('AST%', fontsize=15)

plt.grid(False)

# %%
'POS', 'BODY FAT %', 'HAND LENGTH (inches)', 'HAND WIDTH (inches)',
       'HEIGHT W/O SHOES', 'HEIGHT W/ SHOES', 'STANDING REACH', 'WEIGHT (LBS)',
       'WINGSPAN'

# %%
d_set["height_w/o_shoes(cm)"] = d_set["height_w/o_shoes"].map(lambda x: round((float(x.split("'")[1]) / 12) +  float(x.split("'")[0])) * 30.25, 2)
d_set["wingspan(cm)"] = d_set["wingspan"].map(lambda x: round((float(x.split("'")[1]) / 12) +  float(x.split("'")[0])) * 30.25, 2)

# %%
d_set["height_w/o_shoes_f"] = d_set["height_w/o_shoes"].map(lambda x: float(x.split("'")[0]))
d_set["height_w/o_shoes_in"] = d_set["height_w/o_shoes"].map(lambda x: float(x.split("'")[1]) / 12)
d_set["height_w/o_shoes(cm)"] = round((d_set["height_w/o_shoes_f"] + d_set["height_w/o_shoes_in"]) * 30.25, 2)
d_set["wingspan(cm)"] = d_set["wingspan"].map(lambda x: round((float(x.split("'")[0]) + float(x.split("'")[1]) / 12)*30.25, 2))

# %%
d_set = d_set[d_set['POS_abb'].isin(['Forward', 'C/F', 'Center'])]

# %%
fig, ax = plt.subplots()
d_set.plot.scatter('height_w/o_shoes(cm)', 'wingspan(cm)', figsize=(20, 10), fontsize=15, ax=ax)
for k, point in d_set.iterrows():
    #if k in ["Rudy Gobert", "Joel Embiid", "Clint Capela"]:
    #    ax.annotate(str(k), (point['DFGA'], point['DFG%']), color='red', fontsize=15, fontweight='bold')
        
    if point['POS_abb'] == 'Guard':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['wingspan(cm)']), color='darkturquoise', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'G/F':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['wingspan(cm)']), color='darkcyan', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'Forward':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['wingspan(cm)']), color='darksalmon', fontsize=15, fontweight='bold')
    elif point['POS_abb'] == 'C/F':
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['wingspan(cm)']), color='indianred', fontsize=15, fontweight='bold')
    else:
        ax.annotate(str(k), (point['height_w/o_shoes(cm)'], point['wingspan(cm)']), color='orangered', fontsize=15, fontweight='bold')
plt.title('Combine result: height_w/o_shoes(cm) - Wingspan(cm) / Guard and G/Fs', fontsize=20, fontweight="bold")
plt.xlabel('height_w/o_shoes(cm)', fontsize=15)
plt.ylabel('Wingspan(cm)', fontsize=15)

g1_patch = mpatches.Patch(color='darkturquoise', label='Guard')
g2_patch = mpatches.Patch(color='darkcyan', label='G/F')
g3_patch = mpatches.Patch(color='darksalmon', label='Forward')
g4_patch = mpatches.Patch(color='indianred', label='C/F')
g5_patch = mpatches.Patch(color='orangered', label='Center')
plt.legend(handles=[g1_patch, g2_patch, g3_patch, g4_patch, g5_patch], fontsize=17)
ax.grid(False)

# %%
fig, ax = plt.subplots(2, sharex=False)
ax[0].set_title('Pull-up attempts and FG%/3P% in Conf. Semi-Finals', fontsize=20, fontweight="bold")
d_set.plot.scatter('FGA', 'FG%', figsize=(20, 10), fontsize=15, ax=ax[0])
for k, point in d_set.iterrows():
    if k in ["Kawhi Leonard", "Kevin Durant", "CJ McCollum", "Jamal Murray"]:
        ax[0].annotate(str(k), (point['FGA'], point['FG%']), color='blue', fontsize=15, fontweight='bold')
    else:
        ax[0].annotate(str(k), (point['FGA'], point['FG%']), color='darkcyan', fontsize=15, fontweight='bold')

plt.xlabel('DRIVES PER GAME', fontsize=15)
plt.ylabel('PTS%', fontsize=15)
ax[0].grid(False)

#fig2, ax2 = plt.subplots(1, 2, 2, sharex=ax1)
d_set.plot.scatter('3PA', '3P%', figsize=(20, 10), fontsize=15, ax=ax[1])
for k, point in d_set.iterrows():
    if k in ["Damian Lillard", "Stephen Curry", "James Harden", "Jamal M"]:
        ax[1].annotate(str(k), (point['3PA'], point['3P%']), color='orangered', fontsize=15, fontweight='bold')
    else:
        ax[1].annotate(str(k), (point['3PA'], point['3P%']), color='darksalmon', fontsize=15, fontweight='bold')
#plt.title('PTS% of players who attempt more than 3 drives per game', fontsize=20, fontweight="bold")
#plt.xlabel('DRIVES PER GAME', fontsize=15)
#plt.ylabel('PTS%', fontsize=15)

ax[1].grid(False)
